# %% [markdown]
# # Welcome To pandas

# %%
import numpy as np
import pandas as pd

# %%
dict ={
    "name":["Akshay","Mrudul","Vaibhav","Kaushal"],
    "city":["Kharghar","Nagpur","Delhi","Kalyan"],
    "marks":[28,88,96,90]
    
}

# %% [markdown]
# Below code makes dataframe of given dictionary

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#       name      city  marks
# 0   Akshay  Kharghar     28
# 1   Mrudul    Nagpur     88
# 2  Vaibhav     Delhi     96
# 3  Kaushal    Kalyan     90

# %% [markdown]
# It makes dataframe of array as well as shon below

# %%
myarr = np.array([1,2,3,4])

# %%
df1 = pd.DataFrame(myarr)

# %%
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df
# Out:
#       name      city  marks
# 0   Akshay  Kharghar     28
# 1   Mrudul    Nagpur     88
# 2  Vaibhav     Delhi     96
# 3  Kaushal    Kalyan     90

# %% [markdown]
# If we want to make csv file from given or created Dataframe then,the file is created here hello.csv is created having dataframe df

# %%
df.to_csv("hello.csv")

# %% [markdown]
# If we don't want to have index in our csv file we can do following

# %%
df.to_csv("hello1.csv",index=False)

# %% [markdown]
# if we want to see only some starting dataframes of dataframe we do following(It is showing first 2 as we have wriiten 2 in parameter)

# %%
df.head(2)
# Out:
#      name      city  marks
# 0  Akshay  Kharghar     28
# 1  Mrudul    Nagpur     88

# %% [markdown]
# if we want to see only some last dataframes of dataframe we do following(It is showing last 2 as we have wriiten 2 in parameter)

# %%
df.tail(2)
# Out:
#       name    city  marks
# 2  Vaibhav   Delhi     96
# 3  Kaushal  Kalyan     90

# %% [markdown]
# Below gives brief analysis of the dataframe it describes it with certain properties

# %%
df.describe()
# Out:
#          marks
# count   4.0000
# mean   75.5000
# std    31.8486
# min    28.0000
# 25%    73.0000
# 50%    89.0000
# 75%    91.5000
# max    96.0000

# %% [markdown]
# If we want to read CSV file then we do following

# %%
read_csv = pd.read_csv("hello.csv")

# %%
read_csv
# Out:
#    Unnamed: 0     name      city  marks
# 0           0   Akshay  Kharghar     28
# 1           1   Mrudul    Nagpur     88
# 2           2  Vaibhav     Delhi     96
# 3           3  Kaushal    Kalyan     90

# %% [markdown]
# if we want to access specific columns

# %%
read_csv["name"]
# Out:
# 0     Akshay
# 1     Mrudul
# 2    Vaibhav
# 3    Kaushal
# Name: name, dtype: object

# %%
read_csv["name"][0]
# Out:
# 'Akshay'

# %% [markdown]
# Though it gives warning, if we want to change value in dataframe

# %%
read_csv["marks"][0]=20
# Out:
# <ipython-input-18-50a8e229b05e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_csv["marks"][0]=20

# %%
read_csv["marks"][0]
# Out:
# 20

# %% [markdown]
# Below code creates a random series of 34 elements

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.938870
# 1     0.288025
# 2     0.382608
# 3     0.098377
# 4     0.834202
# 5     0.856779
# 6     0.004168
# 7     0.955754
# 8     0.862946
# 9     0.422274
# 10    0.137880
# 11    0.544790
# 12    0.288840
# 13    0.379165
# 14    0.406959
# 15    0.027840
# 16    0.850789
# 17    0.076947
# 18    0.246866
# 19    0.611479
# 20    0.376154
# 21    0.539982
# 22    0.934406
# 23    0.340708
# 24    0.392105
# 25    0.274422
# 26    0.175586
# 27    0.491901
# 28    0.112696
# 29    0.328240
# 30    0.228429
# 31    0.974108
# 32    0.312242
# 33    0.875020
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.483614  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.525498    0.514517    0.472069    0.508697    0.508403
# std      0.296460    0.300127    0.285001    0.280337    0.283827
# min      0.000310    0.000348    0.005075    0.003718    0.000711
# 25%      0.250525    0.247906    0.223606    0.285901    0.273051
# 50%      0.555686    0.555863    0.456642    0.512748    0.525599
# 75%      0.780745    0.771702    0.724553    0.746655    0.742097
# max      0.999956    0.998927    0.999953    0.996633    0.990205

# %%
newdf.head(4)
# Out:
#           0         1         2         3         4
# 0  0.483614  0.554858  0.991613  0.729500  0.115309
# 1  0.622327  0.309980  0.091801  0.986203  0.688083
# 2  0.995199  0.006035  0.143225  0.199244  0.014979
# 3  0.888106  0.856223  0.223260  0.824350  0.137994

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# If we suppose introduce string at [0][0] then column of that dataframe will have datatype as object now

# %%
newdf[0][0]="helloo"

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf
# Out:
#             0         1         2         3         4
# 0      helloo  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdf[0][0]=0.145129
# Out:
# <ipython-input-34-cb4396e8c1db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[0][0]=0.145129

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.145129  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %% [markdown]
# If we want to have numpy from dataframe we do following

# %%
newdf.to_numpy()
# Out:
# array([[0.145129, 0.5548579426474817, 0.9916129679919734,
#         0.729500331942013, 0.11530922231570018],
#        [0.6223270558917045, 0.3099800354618175, 0.09180069509595667,
#         0.9862026522149739, 0.6880830619781472],
#        [0.9951988873034291, 0.006035145552858001, 0.14322509020291319,
#         0.19924434749324937, 0.014979245027152532],
#        ...,
#        [0.8943692281455937, 0.5385663187365726, 0.7918901904930025,
#         0.5415050335130682, 0.44062602840967724],
#        [0.8850614546414834, 0.5685560887019391, 0.06964058377080629,
#         0.2537652854007848, 0.754986466159713],
#        [0.5106459940273541, 0.2454531290670463, 0.5989085499474832,
#         0.3426210642739651, 0.818565694358696]], dtype=object)

# %% [markdown]
# Below code became transpose of original dataframe

# %%
newdf.T
# Out:
#         0          1           2         3         4         5         6    \
# 0  0.145129   0.622327    0.995199  0.888106  0.695386  0.673825  0.928909
# 1  0.554858    0.30998  0.00603515  0.856223   0.58174  0.986341  0.659617
# 2  0.991613  0.0918007    0.143225   0.22326  0.684012  0.907997  0.404458
# 3    0.7295   0.986203    0.199244   0.82435   0.52947  0.830569  0.288489
# 4  0.115309   0.688083   0.0149792  0.137994  0.339184  0.587966  0.215142
#
#         7         8         9    ...        324        325         326  \
# 0  0.569532  0.583576  0.860226  ...  0.0223679   0.375978    0.564954
# 1   0.02144   0.60726  0.910176  ...   0.141333   0.418452  0.00292272
# 2  0.207825  0.455606   0.76377  ...    0.58634   0.247596    0.823715
# 3  0.964303   0.23775  0.670005  ...    0.68134  0.0686641    0.896332
# 4  0.403307  0.401861  0.648651  ...   0.858251   0.444853    0.622744
#
#         327        328       329       330       331        332       333
# 0  0.824487  0.0857665  0.831073  0.868297  0.894369   0.885061  0.510646
# 1  0.927281   0.659875  0.220298  0.381088  0.538566   0.568556  0.245453
# 2  0.698528   0.938941  0.736724  0.919554   0.79189  0.0696406  0.598909
# 3  0.313656  0.0241175  0.575274  0.596844  0.541505   0.253765  0.342621
# 4  0.142821   0.834905  0.298231  0.741276  0.440626   0.754986  0.818566
#
# [5 rows x 334 columns]

# %%
newdf.head(4)
# Out:
#           0         1         2         3         4
# 0  0.145129  0.554858  0.991613  0.729500  0.115309
# 1  0.622327  0.309980  0.091801  0.986203  0.688083
# 2  0.995199  0.006035  0.143225  0.199244  0.014979
# 3  0.888106  0.856223  0.223260  0.824350  0.137994

# %%
newdf.sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3         4
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# ..        ...       ...       ...       ...       ...
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 0    0.145129  0.554858  0.991613  0.729500  0.115309
#
# [334 rows x 5 columns]

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.115309  0.729500  0.991613  0.554858  0.145129
# 1    0.688083  0.986203  0.091801  0.309980  0.622327
# 2    0.014979  0.199244  0.143225  0.006035  0.995199
# 3    0.137994  0.824350  0.223260  0.856223  0.888106
# 4    0.339184  0.529470  0.684012  0.581740  0.695386
# ..        ...       ...       ...       ...       ...
# 329  0.298231  0.575274  0.736724  0.220298  0.831073
# 330  0.741276  0.596844  0.919554  0.381088  0.868297
# 331  0.440626  0.541505  0.791890  0.538566  0.894369
# 332  0.754986  0.253765  0.069641  0.568556  0.885061
# 333  0.818566  0.342621  0.598909  0.245453  0.510646
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.145129  0.554858  0.991613  0.729500  0.115309
# 1  0.622327  0.309980  0.091801  0.986203  0.688083
# 2  0.995199  0.006035  0.143225  0.199244  0.014979
# 3  0.888106  0.856223  0.223260  0.824350  0.137994
# 4  0.695386  0.581740  0.684012  0.529470  0.339184

# %%
newdf[0]
# Out:
# 0      0.145129
# 1      0.622327
# 2      0.995199
# 3      0.888106
# 4      0.695386
#          ...
# 329    0.831073
# 330    0.868297
# 331    0.894369
# 332    0.885061
# 333    0.510646
# Name: 0, Length: 334, dtype: object

# %%
newdf[0].dtype
# Out:
# dtype('O')

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Below newdf2 is not created or copied the dataframe nedf it's just a reference having same memory location if you change in newdf2 it gets change in newdf as well see in belo example

# %%
newdf2 = newdf

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.145129  0.554858  0.991613  0.729500  0.115309
# 1  0.622327  0.309980  0.091801  0.986203  0.688083
# 2  0.995199  0.006035  0.143225  0.199244  0.014979
# 3  0.888106  0.856223  0.223260  0.824350  0.137994
# 4  0.695386  0.581740  0.684012  0.529470  0.339184

# %%
newdf2[0][0]=0.1
# Out:
# <ipython-input-47-dd6fbea83fd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0]=0.1

# %%
newdf
# Out:
#             0         1         2         3         4
# 0         0.1  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %% [markdown]
# So if we want to make a copy then we do following in that case it will have it's own dataframe

# %%
newdf2 = newdf.copy()

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0         0.1  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
newdf2[0][0]=0
# Out:
# <ipython-input-51-f4979bdf3712>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0]=0

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0           0  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
newdf
# Out:
#             0         1         2         3         4
# 0         0.1  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
newdf[0][0]=10
# Out:
# <ipython-input-54-168d58f3b26b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[0][0]=10

# %%
newdf
# Out:
#             0         1         2         3         4
# 0          10  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %% [markdown]
# See below using loc at 0 th row and 0 th column and assigning value to it is efficient way as it didn't gave error

# %%
newdf.loc[0,0]=0.014564

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.014564  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %% [markdown]
# Since there are 5 columns we have given ABCDE assign each alphabet per column

# %%
newdf.columns = list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0    0.014564  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %% [markdown]
# Now we have table with different column heading now if we have to assign some values we need to this new index

# %%
newdf.loc[0,'A']=0

# %%
newdf
# Out:
#             A         B         C         D         E
# 0           0  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %% [markdown]
# Here instead of 'A' if we tried using 0 then it will create one more new column having index name 0

# %%
newdf.loc[0,0]=12

# %%
newdf
# Out:
#             A         B         C         D         E     0
# 0           0  0.554858  0.991613  0.729500  0.115309  12.0
# 1    0.622327  0.309980  0.091801  0.986203  0.688083   NaN
# 2    0.995199  0.006035  0.143225  0.199244  0.014979   NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994   NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184   NaN
# ..        ...       ...       ...       ...       ...   ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231   NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276   NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626   NaN
# 332  0.885061  0.568556  0.069641  0.253765  0.754986   NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566   NaN
#
# [334 rows x 6 columns]

# %% [markdown]
# Now we want to delete column having index 0 then we need to use axis 1 as it is use for column and using drop

# %%
newdf.drop(0,axis=1)
# Out:
#             A         B         C         D         E
# 0           0  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
newdf.drop(0,axis=0)
# Out:
#             A         B         C         D         E   0
# 1    0.622327  0.309980  0.091801  0.986203  0.688083 NaN
# 2    0.995199  0.006035  0.143225  0.199244  0.014979 NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994 NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184 NaN
# 5    0.673825  0.986341  0.907997  0.830569  0.587966 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.831073  0.220298  0.736724  0.575274  0.298231 NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276 NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626 NaN
# 332  0.885061  0.568556  0.069641  0.253765  0.754986 NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566 NaN
#
# [333 rows x 6 columns]

# %% [markdown]
# If we want to access specific rows and specific columns we do following

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.091801  0.986203
# 2  0.143225  0.199244

# %% [markdown]
# if we want all rows of particular columns

# %%
newdf.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.991613  0.729500
# 1    0.091801  0.986203
# 2    0.143225  0.199244
# 3    0.223260  0.824350
# 4    0.684012  0.529470
# ..        ...       ...
# 329  0.736724  0.575274
# 330  0.919554  0.596844
# 331  0.791890  0.541505
# 332  0.069641  0.253765
# 333  0.598909  0.342621
#
# [334 rows x 2 columns]

# %% [markdown]
# if we want all columns of particular rows

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.622327  0.309980  0.091801  0.986203  0.688083 NaN
# 2  0.995199  0.006035  0.143225  0.199244  0.014979 NaN

# %% [markdown]
# The below Code gives all the rows in column A having value more than 0.3

# %%
newdf.loc[(newdf['A']>0.3)]
# Out:
#             A         B         C         D         E   0
# 1    0.622327  0.309980  0.091801  0.986203  0.688083 NaN
# 2    0.995199  0.006035  0.143225  0.199244  0.014979 NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994 NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184 NaN
# 5    0.673825  0.986341  0.907997  0.830569  0.587966 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.831073  0.220298  0.736724  0.575274  0.298231 NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276 NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626 NaN
# 332  0.885061  0.568556  0.069641  0.253765  0.754986 NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566 NaN
#
# [237 rows x 6 columns]

# %% [markdown]
# We can also use conditons for above problems

# %%
newdf.loc[(newdf['A']>0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E   0
# 2    0.995199  0.006035  0.143225  0.199244  0.014979 NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994 NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184 NaN
# 5    0.673825  0.986341  0.907997  0.830569  0.587966 NaN
# 6    0.928909  0.659617  0.404458  0.288489  0.215142 NaN
# ..        ...       ...       ...       ...       ...  ..
# 327  0.824487  0.927281  0.698528  0.313656  0.142821 NaN
# 329  0.831073  0.220298  0.736724  0.575274  0.298231 NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276 NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626 NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566 NaN
#
# [209 rows x 6 columns]

# %% [markdown]
# If we want access it by proper name then use loc

# %%
newdf.loc[0,'C']
# Out:
# 0.9916129679919734

# %% [markdown]
# If we don't care what is index name and give numbering then we use iloc

# %%
newdf.iloc[0,2]
# Out:
# 0.9916129679919734

# %%
newdf.iloc[[1,2],[1,3]]
# Out:
#           B         D
# 1  0.309980  0.986203
# 2  0.006035  0.199244

# %% [markdown]
# For above thing if we want to do same in loc, we do following(using proper name convention)

# %%
newdf.loc[[1,2],['B','D']]
# Out:
#           B         D
# 1  0.309980  0.986203
# 2  0.006035  0.199244

# %%
newdf
# Out:
#             A         B         C         D         E     0
# 0           0  0.554858  0.991613  0.729500  0.115309  12.0
# 1    0.622327  0.309980  0.091801  0.986203  0.688083   NaN
# 2    0.995199  0.006035  0.143225  0.199244  0.014979   NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994   NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184   NaN
# ..        ...       ...       ...       ...       ...   ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231   NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276   NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626   NaN
# 332  0.885061  0.568556  0.069641  0.253765  0.754986   NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566   NaN
#
# [334 rows x 6 columns]

# %% [markdown]
# The below thing drops the row of given name

# %%
newdf.drop(1)
# Out:
#             A         B         C         D         E     0
# 0           0  0.554858  0.991613  0.729500  0.115309  12.0
# 2    0.995199  0.006035  0.143225  0.199244  0.014979   NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994   NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184   NaN
# 5    0.673825  0.986341  0.907997  0.830569  0.587966   NaN
# ..        ...       ...       ...       ...       ...   ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231   NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276   NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626   NaN
# 332  0.885061  0.568556  0.069641  0.253765  0.754986   NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566   NaN
#
# [333 rows x 6 columns]

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E   0
# 1    0.622327  0.309980  0.091801  0.986203  0.688083 NaN
# 2    0.995199  0.006035  0.143225  0.199244  0.014979 NaN
# 3    0.888106  0.856223  0.223260  0.824350  0.137994 NaN
# 4    0.695386  0.581740  0.684012  0.529470  0.339184 NaN
# 5    0.673825  0.986341  0.907997  0.830569  0.587966 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.831073  0.220298  0.736724  0.575274  0.298231 NaN
# 330  0.868297  0.381088  0.919554  0.596844  0.741276 NaN
# 331  0.894369  0.538566  0.791890  0.541505  0.440626 NaN
# 332  0.885061  0.568556  0.069641  0.253765  0.754986 NaN
# 333  0.510646  0.245453  0.598909  0.342621  0.818566 NaN
#
# [333 rows x 6 columns]

# %% [markdown]
# If we want to drop column then

# %%
newdf.drop(['A'],axis=1)
# Out:
#             B         C         D         E     0
# 0    0.554858  0.991613  0.729500  0.115309  12.0
# 1    0.309980  0.091801  0.986203  0.688083   NaN
# 2    0.006035  0.143225  0.199244  0.014979   NaN
# 3    0.856223  0.223260  0.824350  0.137994   NaN
# 4    0.581740  0.684012  0.529470  0.339184   NaN
# ..        ...       ...       ...       ...   ...
# 329  0.220298  0.736724  0.575274  0.298231   NaN
# 330  0.381088  0.919554  0.596844  0.741276   NaN
# 331  0.538566  0.791890  0.541505  0.440626   NaN
# 332  0.568556  0.069641  0.253765  0.754986   NaN
# 333  0.245453  0.598909  0.342621  0.818566   NaN
#
# [334 rows x 5 columns]

# %% [markdown]
# Drop more than 1 columns

# %%
newdf.drop(['A','C'],axis=1)
# Out:
#             B         D         E     0
# 0    0.554858  0.729500  0.115309  12.0
# 1    0.309980  0.986203  0.688083   NaN
# 2    0.006035  0.199244  0.014979   NaN
# 3    0.856223  0.824350  0.137994   NaN
# 4    0.581740  0.529470  0.339184   NaN
# ..        ...       ...       ...   ...
# 329  0.220298  0.575274  0.298231   NaN
# 330  0.381088  0.596844  0.741276   NaN
# 331  0.538566  0.541505  0.440626   NaN
# 332  0.568556  0.253765  0.754986   NaN
# 333  0.245453  0.342621  0.818566   NaN
#
# [334 rows x 4 columns]

# %% [markdown]
# Now whenever we do drop it just return the copy  it do not change the dataframe originally but if we want to do that then we do following

# %%
newdf.drop([0],axis=1,inplace=True)

# %%
newdf
# Out:
#             A         B         C         D         E
# 0           0  0.554858  0.991613  0.729500  0.115309
# 1    0.622327  0.309980  0.091801  0.986203  0.688083
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 3    0.888106  0.856223  0.223260  0.824350  0.137994
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [334 rows x 5 columns]

# %%
newdf.drop([1,3],axis=0,inplace=True)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         0  0.554858  0.991613  0.729500  0.115309
# 2  0.995199  0.006035  0.143225  0.199244  0.014979
# 4  0.695386  0.581740  0.684012  0.529470  0.339184
# 5  0.673825  0.986341  0.907997  0.830569  0.587966
# 6  0.928909  0.659617  0.404458  0.288489  0.215142

# %% [markdown]
# now if we want to reset indexes again and when doing that more column of index comes if we want to avoid as well then we do following

# %%
newdf.reset_index(drop=True)
# Out:
#             A         B         C         D         E
# 0           0  0.554858  0.991613  0.729500  0.115309
# 1    0.995199  0.006035  0.143225  0.199244  0.014979
# 2    0.695386  0.581740  0.684012  0.529470  0.339184
# 3    0.673825  0.986341  0.907997  0.830569  0.587966
# 4    0.928909  0.659617  0.404458  0.288489  0.215142
# ..        ...       ...       ...       ...       ...
# 327  0.831073  0.220298  0.736724  0.575274  0.298231
# 328  0.868297  0.381088  0.919554  0.596844  0.741276
# 329  0.894369  0.538566  0.791890  0.541505  0.440626
# 330  0.885061  0.568556  0.069641  0.253765  0.754986
# 331  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [332 rows x 5 columns]

# %%
newdf
# Out:
#             A         B         C         D         E
# 0           0  0.554858  0.991613  0.729500  0.115309
# 2    0.995199  0.006035  0.143225  0.199244  0.014979
# 4    0.695386  0.581740  0.684012  0.529470  0.339184
# 5    0.673825  0.986341  0.907997  0.830569  0.587966
# 6    0.928909  0.659617  0.404458  0.288489  0.215142
# ..        ...       ...       ...       ...       ...
# 329  0.831073  0.220298  0.736724  0.575274  0.298231
# 330  0.868297  0.381088  0.919554  0.596844  0.741276
# 331  0.894369  0.538566  0.791890  0.541505  0.440626
# 332  0.885061  0.568556  0.069641  0.253765  0.754986
# 333  0.510646  0.245453  0.598909  0.342621  0.818566
#
# [332 rows x 5 columns]

# %% [markdown]
# In below code It check at which index it is NULL at particular column

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 2      False
# 4      False
# 5      False
# 6      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B']=None

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 2      True
# 4      True
# 5      True
# 6      True
#        ...
# 329    True
# 330    True
# 331    True
# 332    True
# 333    True
# Name: B, Length: 332, dtype: bool

# %% [markdown]
# **Note: whenever you want to set or assign a value then use loc or iloc, don't do directly**

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df1
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %% [markdown]
# It drop all rows which contains NaT

# %%
df1.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# In below it will remove row when all the elements in particular row will be NaT

# %%
df1.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.loc[1,'toy']=np.nan

# %%
df1.loc[2,'toy']=np.nan

# %%
df1
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df1.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df1.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   city    4 non-null      object
#  2   marks   4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df1['name'].value_counts(dropna=False)
# Out:
# Batman      1
# Alfred      1
# Catwoman    1
# Name: name, dtype: int64

# %% [markdown]
# To read Excel file

# %%
data = pd.read_excel('book1.xlsx')

# %%
data
# Out:
#    Unnamed: 0  index  name
# 0           0     10   NaN
# 1           1      2   NaN

# %% [markdown]
# If we want to use particular sheet in excel file

# %%
data = pd.read_excel('book1.xlsx',sheet_name="Sheet2")

# %%
data
# Out:
#    Unnamed: 0  index  name
# 0           0     10   NaN
# 1           1      2   NaN

# %%
data = pd.read_excel('book1.xlsx')

# %%
data
# Out:
#    Unnamed: 0  index  name
# 0           0     10   NaN
# 1           1      2   NaN

# %%
data.iloc[0,0]=10

# %%
data
# Out:
#    Unnamed: 0  index  name
# 0          10     10   NaN
# 1           1      2   NaN

# %%
data.to_excel('book1.xlsx',sheet_name="Sheet2")
