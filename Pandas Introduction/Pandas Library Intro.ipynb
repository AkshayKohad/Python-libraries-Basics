# %% [markdown]
# # Welcome To pandas

# %%
import numpy as np
import pandas as pd

# %%
dict ={
    "name":["Akshay","Mrudul","Vaibhav","Kaushal"],
    "city":["Kharghar","Nagpur","Delhi","Kalyan"],
    "marks":[28,88,96,90]
    
}

# %% [markdown]
# Below code makes dataframe of given dictionary

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#       name      city  marks
# 0   Akshay  Kharghar     28
# 1   Mrudul    Nagpur     88
# 2  Vaibhav     Delhi     96
# 3  Kaushal    Kalyan     90

# %% [markdown]
# It makes dataframe of array as well as shon below

# %%
myarr = np.array([1,2,3,4])

# %%
df1 = pd.DataFrame(myarr)

# %%
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df
# Out:
#       name      city  marks
# 0   Akshay  Kharghar     28
# 1   Mrudul    Nagpur     88
# 2  Vaibhav     Delhi     96
# 3  Kaushal    Kalyan     90

# %% [markdown]
# If we want to make csv file from given or created Dataframe then,the file is created here hello.csv is created having dataframe df

# %%
df.to_csv("hello.csv")

# %% [markdown]
# If we don't want to have index in our csv file we can do following

# %%
df.to_csv("hello1.csv",index=False)

# %% [markdown]
# if we want to see only some starting dataframes of dataframe we do following(It is showing first 2 as we have wriiten 2 in parameter)

# %%
df.head(2)
# Out:
#      name      city  marks
# 0  Akshay  Kharghar     28
# 1  Mrudul    Nagpur     88

# %% [markdown]
# if we want to see only some last dataframes of dataframe we do following(It is showing last 2 as we have wriiten 2 in parameter)

# %%
df.tail(2)
# Out:
#       name    city  marks
# 2  Vaibhav   Delhi     96
# 3  Kaushal  Kalyan     90

# %% [markdown]
# Below gives brief analysis of the dataframe it describes it with certain properties

# %%
df.describe()
# Out:
#          marks
# count   4.0000
# mean   75.5000
# std    31.8486
# min    28.0000
# 25%    73.0000
# 50%    89.0000
# 75%    91.5000
# max    96.0000

# %% [markdown]
# If we want to read CSV file then we do following

# %%
read_csv = pd.read_csv("hello.csv")

# %%
read_csv
# Out:
#    Unnamed: 0     name      city  marks
# 0           0   Akshay  Kharghar     28
# 1           1   Mrudul    Nagpur     88
# 2           2  Vaibhav     Delhi     96
# 3           3  Kaushal    Kalyan     90

# %% [markdown]
# if we want to access specific columns

# %%
read_csv["name"]
# Out:
# 0     Akshay
# 1     Mrudul
# 2    Vaibhav
# 3    Kaushal
# Name: name, dtype: object

# %%
read_csv["name"][0]
# Out:
# 'Akshay'

# %% [markdown]
# Though it gives warning, if we want to change value in dataframe

# %%
read_csv["marks"][0]=20
# Out:
# <ipython-input-18-50a8e229b05e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_csv["marks"][0]=20

# %%
read_csv["marks"][0]
# Out:
# 20

# %% [markdown]
# Below code creates a random series of 34 elements

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.253354
# 1     0.609919
# 2     0.228740
# 3     0.518275
# 4     0.989679
# 5     0.751484
# 6     0.444793
# 7     0.684401
# 8     0.889989
# 9     0.202676
# 10    0.618458
# 11    0.418258
# 12    0.267418
# 13    0.028374
# 14    0.234039
# 15    0.360595
# 16    0.133697
# 17    0.187604
# 18    0.499105
# 19    0.955029
# 20    0.143906
# 21    0.125983
# 22    0.788430
# 23    0.286649
# 24    0.843455
# 25    0.020461
# 26    0.820749
# 27    0.897575
# 28    0.405428
# 29    0.648452
# 30    0.610567
# 31    0.686328
# 32    0.763792
# 33    0.697007
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.659557  0.995611  0.753220  0.483209  0.630308
# 1    0.608192  0.503347  0.138555  0.267022  0.648931
# 2    0.419865  0.640023  0.831157  0.889661  0.166879
# 3    0.634239  0.311338  0.616057  0.627913  0.861350
# 4    0.422860  0.714011  0.839512  0.207310  0.526996
# ..        ...       ...       ...       ...       ...
# 329  0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.011410  0.733397  0.410320  0.941770  0.649787
# 331  0.583901  0.300949  0.069390  0.625960  0.257312
# 332  0.818953  0.854854  0.910783  0.444499  0.232614
# 333  0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.516421    0.497383    0.523490    0.508867    0.496356
# std      0.287349    0.284636    0.289289    0.285725    0.288037
# min      0.007733    0.003423    0.000193    0.000042    0.005114
# 25%      0.274584    0.256988    0.272326    0.266055    0.249375
# 50%      0.540712    0.500452    0.550065    0.482914    0.485248
# 75%      0.768095    0.705119    0.778792    0.745693    0.726972
# max      0.996450    0.997677    0.997685    0.997042    0.995763

# %%
newdf.head(4)
# Out:
#           0         1         2         3         4
# 0  0.659557  0.995611  0.753220  0.483209  0.630308
# 1  0.608192  0.503347  0.138555  0.267022  0.648931
# 2  0.419865  0.640023  0.831157  0.889661  0.166879
# 3  0.634239  0.311338  0.616057  0.627913  0.861350

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# If we suppose introduce string at [0][0] then column of that dataframe will have datatype as object now

# %%
newdf[0][0]="helloo"

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf
# Out:
#              0         1         2         3         4
# 0       helloo  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdf[0][0]=0.145129
# Out:
# <ipython-input-34-cb4396e8c1db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[0][0]=0.145129

# %%
newdf
# Out:
#              0         1         2         3         4
# 0     0.145129  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %% [markdown]
# If we want to have numpy from dataframe we do following

# %%
newdf.to_numpy()
# Out:
# array([[0.145129, 0.9956107677137266, 0.753220020252608,
#         0.4832091512522185, 0.6303080453809919],
#        [0.6081923298123926, 0.5033474310097119, 0.13855535563969545,
#         0.26702159370317313, 0.6489310503925166],
#        [0.4198646576406937, 0.6400230286370174, 0.8311565387158109,
#         0.8896611611410806, 0.1668794998173868],
#        ...,
#        [0.5839014330481761, 0.3009493262577273, 0.06939032793360578,
#         0.6259596088162049, 0.2573121424767132],
#        [0.8189534935223078, 0.85485363923317, 0.9107830264477176,
#         0.4444993667659687, 0.23261434306492024],
#        [0.5402965562137789, 0.9548434085074012, 0.1475493413224057,
#         0.6465779346263629, 0.6880140509668159]], dtype=object)

# %% [markdown]
# Below code became transpose of original dataframe

# %%
newdf.T
# Out:
#         0         1         2         3         4         5          6    \
# 0  0.145129  0.608192  0.419865  0.634239   0.42286  0.810421   0.795003
# 1  0.995611  0.503347  0.640023  0.311338  0.714011  0.543641   0.407598
# 2   0.75322  0.138555  0.831157  0.616057  0.839512  0.970762   0.227563
# 3  0.483209  0.267022  0.889661  0.627913   0.20731  0.987247   0.216078
# 4  0.630308  0.648931  0.166879   0.86135  0.526996  0.484281  0.0763816
#
#         7         8          9    ...        324       325       326  \
# 0   0.45998  0.233056  0.0714836  ...  0.0765831  0.920219  0.761462
# 1  0.675533  0.256937   0.244994  ...   0.750696  0.347595  0.983509
# 2  0.621842  0.944171   0.356688  ...   0.955577  0.937923  0.833939
# 3  0.841963  0.402694   0.729633  ...   0.954863  0.492736  0.925075
# 4  0.603542  0.387393   0.992788  ...    0.37874  0.264165  0.973039
#
#         327         328        329        330        331       332       333
# ...

# %%
newdf.head(4)
# Out:
#           0         1         2         3         4
# 0  0.145129  0.995611  0.753220  0.483209  0.630308
# 1  0.608192  0.503347  0.138555  0.267022  0.648931
# 2  0.419865  0.640023  0.831157  0.889661  0.166879
# 3  0.634239  0.311338  0.616057  0.627913  0.861350

# %%
newdf.sort_index(axis=0,ascending=False)
# Out:
#              0         1         2         3         4
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# ..         ...       ...       ...       ...       ...
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 0     0.145129  0.995611  0.753220  0.483209  0.630308
#
# [334 rows x 5 columns]

# %%
newdf.sort_index(axis=1,ascending=False)
# Out:
#             4         3         2         1          0
# 0    0.630308  0.483209  0.753220  0.995611   0.145129
# 1    0.648931  0.267022  0.138555  0.503347   0.608192
# 2    0.166879  0.889661  0.831157  0.640023   0.419865
# 3    0.861350  0.627913  0.616057  0.311338   0.634239
# 4    0.526996  0.207310  0.839512  0.714011    0.42286
# ..        ...       ...       ...       ...        ...
# 329  0.256932  0.058194  0.672871  0.094331   0.900035
# 330  0.649787  0.941770  0.410320  0.733397  0.0114102
# 331  0.257312  0.625960  0.069390  0.300949   0.583901
# 332  0.232614  0.444499  0.910783  0.854854   0.818953
# 333  0.688014  0.646578  0.147549  0.954843   0.540297
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.145129  0.995611  0.753220  0.483209  0.630308
# 1  0.608192  0.503347  0.138555  0.267022  0.648931
# 2  0.419865  0.640023  0.831157  0.889661  0.166879
# 3  0.634239  0.311338  0.616057  0.627913  0.861350
# 4   0.42286  0.714011  0.839512  0.207310  0.526996

# %%
newdf[0]
# Out:
# 0       0.145129
# 1       0.608192
# 2       0.419865
# 3       0.634239
# 4        0.42286
#          ...
# 329     0.900035
# 330    0.0114102
# 331     0.583901
# 332     0.818953
# 333     0.540297
# Name: 0, Length: 334, dtype: object

# %%
newdf[0].dtype
# Out:
# dtype('O')

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Below newdf2 is not created or copied the dataframe nedf it's just a reference having same memory location if you change in newdf2 it gets change in newdf as well see in belo example

# %%
newdf2 = newdf

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.145129  0.995611  0.753220  0.483209  0.630308
# 1  0.608192  0.503347  0.138555  0.267022  0.648931
# 2  0.419865  0.640023  0.831157  0.889661  0.166879
# 3  0.634239  0.311338  0.616057  0.627913  0.861350
# 4   0.42286  0.714011  0.839512  0.207310  0.526996

# %%
newdf2[0][0]=0.1
# Out:
# <ipython-input-47-dd6fbea83fd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0]=0.1

# %%
newdf
# Out:
#              0         1         2         3         4
# 0          0.1  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %% [markdown]
# So if we want to make a copy then we do following in that case it will have it's own dataframe

# %%
newdf2 = newdf.copy()

# %%
newdf2
# Out:
#              0         1         2         3         4
# 0          0.1  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
newdf2[0][0]=0
# Out:
# <ipython-input-51-f4979bdf3712>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0]=0

# %%
newdf2
# Out:
#              0         1         2         3         4
# 0            0  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
newdf
# Out:
#              0         1         2         3         4
# 0          0.1  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
newdf[0][0]=10
# Out:
# <ipython-input-54-168d58f3b26b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[0][0]=10

# %%
newdf
# Out:
#              0         1         2         3         4
# 0           10  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %% [markdown]
# See below using loc at 0 th row and 0 th column and assigning value to it is efficient way as it didn't gave error

# %%
newdf.loc[0,0]=0.014564

# %%
newdf
# Out:
#              0         1         2         3         4
# 0     0.014564  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %% [markdown]
# Since there are 5 columns we have given ABCDE assign each alphabet per column

# %%
newdf.columns = list("ABCDE")

# %%
newdf
# Out:
#              A         B         C         D         E
# 0     0.014564  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %% [markdown]
# Now we have table with different column heading now if we have to assign some values we need to this new index

# %%
newdf.loc[0,'A']=0

# %%
newdf
# Out:
#              A         B         C         D         E
# 0            0  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %% [markdown]
# Here instead of 'A' if we tried using 0 then it will create one more new column having index name 0

# %%
newdf.loc[0,0]=12

# %%
newdf
# Out:
#              A         B         C         D         E     0
# 0            0  0.995611  0.753220  0.483209  0.630308  12.0
# 1     0.608192  0.503347  0.138555  0.267022  0.648931   NaN
# 2     0.419865  0.640023  0.831157  0.889661  0.166879   NaN
# 3     0.634239  0.311338  0.616057  0.627913  0.861350   NaN
# 4      0.42286  0.714011  0.839512  0.207310  0.526996   NaN
# ..         ...       ...       ...       ...       ...   ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932   NaN
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787   NaN
# 331   0.583901  0.300949  0.069390  0.625960  0.257312   NaN
# 332   0.818953  0.854854  0.910783  0.444499  0.232614   NaN
# 333   0.540297  0.954843  0.147549  0.646578  0.688014   NaN
#
# [334 rows x 6 columns]

# %% [markdown]
# Now we want to delete column having index 0 then we need to use axis 1 as it is use for column and using drop

# %%
newdf.drop(0,axis=1)
# Out:
#              A         B         C         D         E
# 0            0  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
newdf.drop(0,axis=0)
# Out:
#              A         B         C         D         E   0
# 1     0.608192  0.503347  0.138555  0.267022  0.648931 NaN
# 2     0.419865  0.640023  0.831157  0.889661  0.166879 NaN
# 3     0.634239  0.311338  0.616057  0.627913  0.861350 NaN
# 4      0.42286  0.714011  0.839512  0.207310  0.526996 NaN
# 5     0.810421  0.543641  0.970762  0.987247  0.484281 NaN
# ..         ...       ...       ...       ...       ...  ..
# 329   0.900035  0.094331  0.672871  0.058194  0.256932 NaN
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787 NaN
# 331   0.583901  0.300949  0.069390  0.625960  0.257312 NaN
# 332   0.818953  0.854854  0.910783  0.444499  0.232614 NaN
# 333   0.540297  0.954843  0.147549  0.646578  0.688014 NaN
#
# [333 rows x 6 columns]

# %% [markdown]
# If we want to access specific rows and specific columns we do following

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.138555  0.267022
# 2  0.831157  0.889661

# %% [markdown]
# if we want all rows of particular columns

# %%
newdf.loc[:,['C','D']]
# Out:
#             C         D
# 0    0.753220  0.483209
# 1    0.138555  0.267022
# 2    0.831157  0.889661
# 3    0.616057  0.627913
# 4    0.839512  0.207310
# ..        ...       ...
# 329  0.672871  0.058194
# 330  0.410320  0.941770
# 331  0.069390  0.625960
# 332  0.910783  0.444499
# 333  0.147549  0.646578
#
# [334 rows x 2 columns]

# %% [markdown]
# if we want all columns of particular rows

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.608192  0.503347  0.138555  0.267022  0.648931 NaN
# 2  0.419865  0.640023  0.831157  0.889661  0.166879 NaN

# %% [markdown]
# The below Code gives all the rows in column A having value more than 0.3

# %%
newdf.loc[(newdf['A']>0.3)]
# Out:
#             A         B         C         D         E   0
# 1    0.608192  0.503347  0.138555  0.267022  0.648931 NaN
# 2    0.419865  0.640023  0.831157  0.889661  0.166879 NaN
# 3    0.634239  0.311338  0.616057  0.627913  0.861350 NaN
# 4     0.42286  0.714011  0.839512  0.207310  0.526996 NaN
# 5    0.810421  0.543641  0.970762  0.987247  0.484281 NaN
# ..        ...       ...       ...       ...       ...  ..
# 328  0.392106  0.006863  0.196896  0.929808  0.993340 NaN
# 329  0.900035  0.094331  0.672871  0.058194  0.256932 NaN
# 331  0.583901  0.300949  0.069390  0.625960  0.257312 NaN
# 332  0.818953  0.854854  0.910783  0.444499  0.232614 NaN
# 333  0.540297  0.954843  0.147549  0.646578  0.688014 NaN
#
# [244 rows x 6 columns]

# %% [markdown]
# We can also use conditons for above problems

# %%
newdf.loc[(newdf['A']>0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E   0
# 1    0.608192  0.503347  0.138555  0.267022  0.648931 NaN
# 2    0.419865  0.640023  0.831157  0.889661  0.166879 NaN
# 3    0.634239  0.311338  0.616057  0.627913  0.861350 NaN
# 4     0.42286  0.714011  0.839512  0.207310  0.526996 NaN
# 5    0.810421  0.543641  0.970762  0.987247  0.484281 NaN
# ..        ...       ...       ...       ...       ...  ..
# 327  0.655308  0.779223  0.144123  0.719529  0.521518 NaN
# 328  0.392106  0.006863  0.196896  0.929808  0.993340 NaN
# 329  0.900035  0.094331  0.672871  0.058194  0.256932 NaN
# 332  0.818953  0.854854  0.910783  0.444499  0.232614 NaN
# 333  0.540297  0.954843  0.147549  0.646578  0.688014 NaN
#
# [225 rows x 6 columns]

# %% [markdown]
# If we want access it by proper name then use loc

# %%
newdf.loc[0,'C']
# Out:
# 0.753220020252608

# %% [markdown]
# If we don't care what is index name and give numbering then we use iloc

# %%
newdf.iloc[0,2]
# Out:
# 0.753220020252608

# %%
newdf.iloc[[1,2],[1,3]]
# Out:
#           B         D
# 1  0.503347  0.267022
# 2  0.640023  0.889661

# %% [markdown]
# For above thing if we want to do same in loc, we do following(using proper name convention)

# %%
newdf.loc[[1,2],['B','D']]
# Out:
#           B         D
# 1  0.503347  0.267022
# 2  0.640023  0.889661

# %%
newdf
# Out:
#              A         B         C         D         E     0
# 0            0  0.995611  0.753220  0.483209  0.630308  12.0
# 1     0.608192  0.503347  0.138555  0.267022  0.648931   NaN
# 2     0.419865  0.640023  0.831157  0.889661  0.166879   NaN
# 3     0.634239  0.311338  0.616057  0.627913  0.861350   NaN
# 4      0.42286  0.714011  0.839512  0.207310  0.526996   NaN
# ..         ...       ...       ...       ...       ...   ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932   NaN
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787   NaN
# 331   0.583901  0.300949  0.069390  0.625960  0.257312   NaN
# 332   0.818953  0.854854  0.910783  0.444499  0.232614   NaN
# 333   0.540297  0.954843  0.147549  0.646578  0.688014   NaN
#
# [334 rows x 6 columns]

# %% [markdown]
# The below thing drops the row of given name

# %%
newdf.drop(1)
# Out:
#              A         B         C         D         E     0
# 0            0  0.995611  0.753220  0.483209  0.630308  12.0
# 2     0.419865  0.640023  0.831157  0.889661  0.166879   NaN
# 3     0.634239  0.311338  0.616057  0.627913  0.861350   NaN
# 4      0.42286  0.714011  0.839512  0.207310  0.526996   NaN
# 5     0.810421  0.543641  0.970762  0.987247  0.484281   NaN
# ..         ...       ...       ...       ...       ...   ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932   NaN
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787   NaN
# 331   0.583901  0.300949  0.069390  0.625960  0.257312   NaN
# 332   0.818953  0.854854  0.910783  0.444499  0.232614   NaN
# 333   0.540297  0.954843  0.147549  0.646578  0.688014   NaN
#
# [333 rows x 6 columns]

# %%
newdf.drop([0])
# Out:
#              A         B         C         D         E   0
# 1     0.608192  0.503347  0.138555  0.267022  0.648931 NaN
# 2     0.419865  0.640023  0.831157  0.889661  0.166879 NaN
# 3     0.634239  0.311338  0.616057  0.627913  0.861350 NaN
# 4      0.42286  0.714011  0.839512  0.207310  0.526996 NaN
# 5     0.810421  0.543641  0.970762  0.987247  0.484281 NaN
# ..         ...       ...       ...       ...       ...  ..
# 329   0.900035  0.094331  0.672871  0.058194  0.256932 NaN
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787 NaN
# 331   0.583901  0.300949  0.069390  0.625960  0.257312 NaN
# 332   0.818953  0.854854  0.910783  0.444499  0.232614 NaN
# 333   0.540297  0.954843  0.147549  0.646578  0.688014 NaN
#
# [333 rows x 6 columns]

# %% [markdown]
# If we want to drop column then

# %%
newdf.drop(['A'],axis=1)
# Out:
#             B         C         D         E     0
# 0    0.995611  0.753220  0.483209  0.630308  12.0
# 1    0.503347  0.138555  0.267022  0.648931   NaN
# 2    0.640023  0.831157  0.889661  0.166879   NaN
# 3    0.311338  0.616057  0.627913  0.861350   NaN
# 4    0.714011  0.839512  0.207310  0.526996   NaN
# ..        ...       ...       ...       ...   ...
# 329  0.094331  0.672871  0.058194  0.256932   NaN
# 330  0.733397  0.410320  0.941770  0.649787   NaN
# 331  0.300949  0.069390  0.625960  0.257312   NaN
# 332  0.854854  0.910783  0.444499  0.232614   NaN
# 333  0.954843  0.147549  0.646578  0.688014   NaN
#
# [334 rows x 5 columns]

# %% [markdown]
# Drop more than 1 columns

# %%
newdf.drop(['A','C'],axis=1)
# Out:
#             B         D         E     0
# 0    0.995611  0.483209  0.630308  12.0
# 1    0.503347  0.267022  0.648931   NaN
# 2    0.640023  0.889661  0.166879   NaN
# 3    0.311338  0.627913  0.861350   NaN
# 4    0.714011  0.207310  0.526996   NaN
# ..        ...       ...       ...   ...
# 329  0.094331  0.058194  0.256932   NaN
# 330  0.733397  0.941770  0.649787   NaN
# 331  0.300949  0.625960  0.257312   NaN
# 332  0.854854  0.444499  0.232614   NaN
# 333  0.954843  0.646578  0.688014   NaN
#
# [334 rows x 4 columns]

# %% [markdown]
# Now whenever we do drop it just return the copy  it do not change the dataframe originally but if we want to do that then we do following

# %%
newdf.drop([0],axis=1,inplace=True)

# %%
newdf
# Out:
#              A         B         C         D         E
# 0            0  0.995611  0.753220  0.483209  0.630308
# 1     0.608192  0.503347  0.138555  0.267022  0.648931
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 3     0.634239  0.311338  0.616057  0.627913  0.861350
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [334 rows x 5 columns]

# %%
newdf.drop([1,3],axis=0,inplace=True)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         0  0.995611  0.753220  0.483209  0.630308
# 2  0.419865  0.640023  0.831157  0.889661  0.166879
# 4   0.42286  0.714011  0.839512  0.207310  0.526996
# 5  0.810421  0.543641  0.970762  0.987247  0.484281
# 6  0.795003  0.407598  0.227563  0.216078  0.076382

# %% [markdown]
# now if we want to reset indexes again and when doing that more column of index comes if we want to avoid as well then we do following

# %%
newdf.reset_index(drop=True)
# Out:
#              A         B         C         D         E
# 0            0  0.995611  0.753220  0.483209  0.630308
# 1     0.419865  0.640023  0.831157  0.889661  0.166879
# 2      0.42286  0.714011  0.839512  0.207310  0.526996
# 3     0.810421  0.543641  0.970762  0.987247  0.484281
# 4     0.795003  0.407598  0.227563  0.216078  0.076382
# ..         ...       ...       ...       ...       ...
# 327   0.900035  0.094331  0.672871  0.058194  0.256932
# 328  0.0114102  0.733397  0.410320  0.941770  0.649787
# 329   0.583901  0.300949  0.069390  0.625960  0.257312
# 330   0.818953  0.854854  0.910783  0.444499  0.232614
# 331   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [332 rows x 5 columns]

# %%
newdf
# Out:
#              A         B         C         D         E
# 0            0  0.995611  0.753220  0.483209  0.630308
# 2     0.419865  0.640023  0.831157  0.889661  0.166879
# 4      0.42286  0.714011  0.839512  0.207310  0.526996
# 5     0.810421  0.543641  0.970762  0.987247  0.484281
# 6     0.795003  0.407598  0.227563  0.216078  0.076382
# ..         ...       ...       ...       ...       ...
# 329   0.900035  0.094331  0.672871  0.058194  0.256932
# 330  0.0114102  0.733397  0.410320  0.941770  0.649787
# 331   0.583901  0.300949  0.069390  0.625960  0.257312
# 332   0.818953  0.854854  0.910783  0.444499  0.232614
# 333   0.540297  0.954843  0.147549  0.646578  0.688014
#
# [332 rows x 5 columns]

# %% [markdown]
# In below code It check at which index it is NULL at particular column

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 2      False
# 4      False
# 5      False
# 6      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B']=None

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 2      True
# 4      True
# 5      True
# 6      True
#        ...
# 329    True
# 330    True
# 331    True
# 332    True
# 333    True
# Name: B, Length: 332, dtype: bool

# %% [markdown]
# **Note: whenever you want to set or assign a value then use loc or iloc, don't do directly**

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df1
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %% [markdown]
# It drop all rows which contains NaT

# %%
df1.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# In below it will remove row when all the elements in particular row will be NaT

# %%
df1.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df1.loc[1,'toy']=np.nan

# %%
df1.loc[2,'toy']=np.nan

# %%
df1
# Out:
#        name  toy       born
# 0    Alfred  NaN        NaT
# 1    Batman  NaN 1940-04-25
# 2  Catwoman  NaN        NaT

# %%
df1.dropna(how='all',axis=1)
# Out:
#        name       born
# 0    Alfred        NaT
# 1    Batman 1940-04-25
# 2  Catwoman        NaT

# %%
df1.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   city    4 non-null      object
#  2   marks   4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df1['name'].value_counts(dropna=False)
# Out:
# Alfred      1
# Batman      1
# Catwoman    1
# Name: name, dtype: int64

# %% [markdown]
# To read Excel file

# %%
data = pd.read_excel('book1.xlsx')

# %%
data
# Out:
#    index  name
# 0      1   NaN
# 1      2   NaN

# %% [markdown]
# If we want to use particular sheet in excel file

# %%
data = pd.read_excel('book1.xlsx',sheet_name="Sheet2")

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = pd.read_excel('book1.xlsx')

# %%
data
# Out:
#    index  name
# 0      1   NaN
# 1      2   NaN

# %%
data.iloc[0,0]=10

# %%
data
# Out:
#    index  name
# 0     10   NaN
# 1      2   NaN

# %%
data.to_excel('book1.xlsx',sheet_name="Sheet2")
